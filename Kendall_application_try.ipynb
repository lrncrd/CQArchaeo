# %%
from cqarcheo import cqa_analysis

# %%
cqa_analysis(r'OR_3_4.xlsx', min_data_sample = 7, max_data_sample = 200, min_quantum = 4, max_quantum = 24, step = 0.02, Montecarlo_sim = True, mc_parameter = 0.15, mc_iterations = 100)
# Out:
# Highest 'Phi_q_values': 7.60, corrisponding to quantum: 9.94
# 100%|██████████| 100/100 [00:16<00:00,  6.15it/s]
#       Phi_q_values  Quanta
# 0         3.136800    4.00
# 1         2.728424    4.02
# 2         2.459730    4.04
# 3         2.406665    4.06
# 4         2.046590    4.08
# ...            ...     ...
# 996     -11.025066   23.92
# 997     -11.029197   23.94
# 998     -11.033863   23.96
# 999     -11.039057   23.98
# 1000    -11.044774   24.00
#
# [1001 rows x 2 columns]
