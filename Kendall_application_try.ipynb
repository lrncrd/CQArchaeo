# %%
from cqarcheo import CQAnalysis, compare_quantograms

# %%
cqa = CQAnalysis(r'data.xlsx', min_data_sample = 7, max_data_sample = 200, min_quantum = 4, max_quantum = 24, step = 0.02, Montecarlo_sim = True, mc_parameter = 0.15, mc_iterations = 100)
# Out:
# Highest 'φ(q)': 2.02, corrisponding to quantum: 8.64
# Computing Montecarlo simulation: 100%|██████████| 100/100 [00:28<00:00,  3.52it/s]

# %%
cqa.plot_quantogram(figsize=(10, 6), plot_best_quantum=True, save=False, dpi=300)

# %%
cqa_2 = CQAnalysis(r'data2.xlsx', min_data_sample = 7, max_data_sample = 200, min_quantum = 4, max_quantum = 24, step = 0.02, Montecarlo_sim = True, mc_parameter = 0.15, mc_iterations = 100)
# Out:
# Highest 'φ(q)': 4.38, corrisponding to quantum: 9.44
# Computing Montecarlo simulation: 100%|██████████| 100/100 [00:30<00:00,  3.31it/s]

# %%
cqa_3 = CQAnalysis(r'data3.xlsx', min_data_sample = 7, max_data_sample = 200, min_quantum = 4, max_quantum = 30, step = 0.02, Montecarlo_sim = True, mc_parameter = 0.15, mc_iterations = 100)
# Out:
# Highest 'φ(q)': 4.38, corrisponding to quantum: 9.44
# Computing Montecarlo simulation: 100%|██████████| 100/100 [00:37<00:00,  2.63it/s]

# %%
compare_quantograms(quantogram_list = [cqa, cqa_2, cqa_3], figsize=(10, 6), 
                    color_list=["black", "green", "blue"], alpha_list=[0.2, 1, 1],
                    label_list=None, plot_montecarlo_bound=[True, True, True])
