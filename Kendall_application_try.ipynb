# %%
from cqarcheo import CQAnalysis

# %%
cqa = CQAnalysis(r'data/OR_3_4.xlsx', min_data_sample = 7, max_data_sample = 200, min_quantum = 4, max_quantum = 24, step = 0.02, Montecarlo_sim = False, mc_parameter = 0.15, mc_iterations = 100)
# Out:
# Highest 'Phi_q_values': 7.60, corrisponding to quantum: 9.94

# %%
cqa.plot_quantogram(figsize=(10, 6), plot_best_quantum=True, save=False, dpi=300)
